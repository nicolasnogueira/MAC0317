# %% [markdown]
# # Exemplos de carregamento de sinais de áudio e vídeo de urls e arquivos locais

# %%
import io
from urllib.request import urlopen
import scipy.io.wavfile as wavfile
import soundfile as sf
from imageio import imread
import matplotlib.pyplot as plt
import IPython.display as ipd

# %%
# para abrir arquivo wav de url:
url="http://static1.grsites.com/archive/sounds/bells/bells004.wav"
x, rate = sf.read(io.BytesIO(urlopen(url).read()))
plt.plot(x)
plt.show()
ipd.Audio(x.T, rate=rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# para abrir arquivo wav local:
rate, x = wavfile.read('bells004.wav')
plt.plot(x)
plt.show()
ipd.Audio(x.T, rate=rate)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-503c17109094> in <module>()
#       1 # para abrir arquivo wav local:
# ----> 2 rate, x = wavfile.read('bells004.wav')
#       3 plt.plot(x)
#       4 plt.show()
#       5 ipd.Audio(x.T, rate=rate)
#
# /home/nicolas/anaconda3/lib/python3.6/site-packages/scipy/io/wavfile.py in read(filename, mmap)
#     231         mmap = False
#     232     else:
# --> 233         fid = open(filename, 'rb')
#     234
#     235     try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'bells004.wav'

# %%
# para abrir imagem de url
url = "http://sutherncharm.files.wordpress.com/2009/09/double-ferris.jpg"
M = imread(urlopen(url).read())
plt.imshow(M)

# %%
M = imread("double-ferris.jpg")
plt.imshow(M)
